# %% [markdown]
# # Import libraries

# %%
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

from random import random

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading data & preprocessing

# %%
path_to_colloid_data = './../data/colloidal_parameters.xlsx'

# %%
data = pd.read_excel(path_to_colloid_data)

data.head(3)
# Out:
#    Шифр    PDI  dсредний, нм  Z, мВ
# 0     1  0.496        1417.0   -8.2
# 1     2  0.301         352.9  -28.0
# 2     3  0.916        3286.3  -33.5

# %%
columns = {
    'Шифр': 'id',
    'PDI': '$ИПД$',
    'dсредний, нм': '$d_{ср}, нм$',
    'Z, мВ': '$ζ, мВ$'
}

initial_data = data.rename(columns=columns)

initial_data.index = initial_data['id']
initial_data.drop(columns=['id'], inplace=True)

initial_data.head(3)
# Out:
#     $ИПД$  $d_{ср}, нм$  $ζ, мВ$
# id
# 1   0.496        1417.0     -8.2
# 2   0.301         352.9    -28.0
# 3   0.916        3286.3    -33.5

# %%
samples_preparation = [
    'MFGO, разб. 1:20',
    'HGO, 0.0116 г в 25 мл H2O',
    'GO, RusGraphene, 2 г в 1000 мл H2O',
    'rGO, RusGraphene, 2 г в 1000 мл H2O',
    'GO, RusGraphene, 2 г в 1000 мл H2O',
    'GO, RusGraphene, 1.00 г в 250 мл H2O',
    'rGO, RusGraphene, 0.20 г в 100 мл H2O',
    'GO, RusGraphene, 1.00 г в 250 мл H2O',
    'GO, USA, 0.1 г в 100 мл H2O',
    'GO, RusGraphene, 2 г в 1000 мл H2O',
    'Образец 8 после диализа 7 дней, H2O, стакан 1 л, замена воды каждые 2 дня',
    'Образец 8 после диализа 7 дней, H2O, стакан 1 л, замена воды каждые 2 дня',
    'Образец 8 после диализа 3.5 кДа, конд. 7 дней в H2O',
    'Образец 8 после диализа 3.5 кДа, конд. 7 дней в ЭДТА 0.05 М',
    'Образец 10 после диализа 3.5 кДа, конд.',
    'Образец 8 после диализа 3.5 кДа, конд. 7 дней в ЭДТА 0.05 М (повторное использование)',
    'Образец 9 после диализа 14 кДа, конд. 7 дней в ЭДТА 0.05М',
    'Образец 9 после диализа 14 кДа 75 мм, конд. 7 дней в ЭДТА 0.05М',
    'Образец 9 после диализа 14 кДа 75 мм, конд. 7 дней в ЭДТА 0.05М (повторное использование)',
    'Образец 11 после диализа 2 дня, H2O, 1 кДа',
    'Образец 11 после диализа 5 дней, H2O, 14 кДа 75 мм',
    'Образец 9 после диализа при 25°С 14 кДа, конд. 7 дней в ЭДТА 0.05М',
    'Образец 9 после диализа при 45°С 14 кДа, конд. 7 дней в ЭДТА 0.05М',
    'Образец 13 после диализа 0.5 кДа, конд. 7 дней в ЭДТА 0.05М',
    'Образец 30 после диализа 12 дней, 14 кДа, конд. 7 дней в ЭДТА 0.05М'
]

samples_type = [
    '$GO$',
    '$GO$',
    '$GO$',
    '$rGO$',
    '$GO$',
    '$GO$',
    '$rGO$',
    '$GO$',
    '$GO$',
    '$GO$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$rGO$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$',
    '$GO_{d}$'
]

samples_class = [0 if el == '$rGO$' else 1 if el == '$GO$' else 2 for el in samples_type]

# %%
samples_description = pd.DataFrame(
    {
        'Description': samples_preparation,
        'Тип образца': samples_type,
        'Class': samples_class
    }
)

samples_description.index = initial_data.index

print(samples_description.shape)
samples_description.head(3)
# Out:
# (25, 3)
#                            Description Тип образца  Class
# id
# 1                     MFGO, разб. 1:20        $GO$      1
# 2            HGO, 0.0116 г в 25 мл H2O        $GO$      1
# 3   GO, RusGraphene, 2 г в 1000 мл H2O        $GO$      1

# %%
samples_description['Тип образца'] = samples_description['Тип образца'].apply(
    lambda x:
    '$ОГ$' if x == '$GO$'
    else '$вОГ$' if x == '$rGO$'
    else '$ОГ_{диализ}$' if x == '$GO_{d}$'
    else x
)

print(samples_description.shape)
samples_description.head(3)
# Out:
# (25, 3)
#                            Description Тип образца  Class
# id
# 1                     MFGO, разб. 1:20        $ОГ$      1
# 2            HGO, 0.0116 г в 25 мл H2O        $ОГ$      1
# 3   GO, RusGraphene, 2 г в 1000 мл H2O        $ОГ$      1

# %%
samples_description['Тип образца'].value_counts()
# Out:
# Тип образца
# $ОГ_{диализ}$    14
# $ОГ$              8
# $вОГ$             3
# Name: count, dtype: int64

# %%
initial_data = pd.concat([initial_data, samples_description], axis=1)

initial_data['Class'] = initial_data['Class'].astype('int')

initial_data.head(3)
# Out:
#     $ИПД$  $d_{ср}, нм$  $ζ, мВ$                         Description  \
# id
# 1   0.496        1417.0     -8.2                    MFGO, разб. 1:20
# 2   0.301         352.9    -28.0           HGO, 0.0116 г в 25 мл H2O
# 3   0.916        3286.3    -33.5  GO, RusGraphene, 2 г в 1000 мл H2O
#
#    Тип образца  Class
# id
# 1         $ОГ$      1
# 2         $ОГ$      1
# 3         $ОГ$      1

# %% [markdown]
# # Descriptive Statistics

# %%
columns_to_visualization = [
    '$ИПД$',
    '$d_{ср}, нм$',
    '$ζ, мВ$',
    'Тип образца'
]

data_visualization = initial_data[columns_to_visualization]

# %%
data_visualization.columns
# Out:
# Index(['$ИПД$', '$d_{ср}, нм$', '$ζ, мВ$', 'Тип образца'], dtype='object')

# %%
path_to_save = './../results/descriptive_statistics'

# %% [markdown]
# ## Histogram

# %%
# fig = plt.figure(figsize=(10, 10))

sns.set_theme()

g = sns.FacetGrid(data_visualization, col='Тип образца', hue='Тип образца', palette='inferno')
g.map(sns.histplot, '$ИПД$', bins='auto')
g.set_axis_labels(x_var=None, y_var='$Count$')
g.savefig(path_to_save + '/hist_pdi.png', dpi=600)

g = sns.FacetGrid(data_visualization, col='Тип образца', hue='Тип образца', palette='inferno')
g.map(sns.histplot, '$d_{ср}, нм$', bins='auto')
g.set_axis_labels(x_var=None, y_var='$Count$')
g.savefig(path_to_save + '/hist_d.png', dpi=600)

g = sns.FacetGrid(data_visualization, col='Тип образца', hue='Тип образца', palette='inferno')
g.map(sns.histplot, '$ζ, мВ$', bins='auto')
g.set_axis_labels(x_var=None, y_var='$Count$')
g.savefig(path_to_save + '/hist_z.png', dpi=600)

# %% [markdown]
# ## Pairplot

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 600

sns.set_theme()

columns_to_visualization = [
    '$ИПД$',
    '$d_{ср}, нм$',
    '$ζ, мВ$',
    'Тип образца'
]

# palette: inferno, mako, coolwarm

plot_kws = {
    's': 150,
    'alpha': 0.6
}

diag_kws = {
    'fill': True,
    'alpha': 0.4
}

pair_plot = sns.pairplot(data=data_visualization,
                         hue='Тип образца',
                         diag_kind='hist',
                         palette='mako',
                         size=3.0,
                         height=2.5,
                         aspect=1,
                         corner=True,
                         plot_kws=plot_kws,
                         diag_kws=diag_kws
                        )



plt.tight_layout()
plt.savefig(path_to_save + '/pairplot.png')
plt.show()

# %% [markdown]
# ## BoxPlot

# %%
tmp = initial_data[['$d_{ср}, нм$', '$ζ, мВ$', 'Тип образца']]

# %%
tmp.loc[tmp['Тип образца'] == '$ОГ_{диализ}$']['$ζ, мВ$'].median()
# Out:
# -28.200000000000003

# %%
tmp.loc[tmp['Тип образца'] == '$вОГ$']['$ζ, мВ$'].median()
# Out:
# -23.3

# %%
tmp.loc[tmp['Тип образца'] == '$ОГ$']['$ζ, мВ$'].median()
# Out:
# -33.35

# %%
sns.set_theme()
plt.style.use('seaborn-v0_8-darkgrid')

parameters = data_visualization.columns[:-1]

nrows = 1
ncols = 3

point_size = 7
point_alpha = 0.9


fig = plt.figure(figsize=(8, 4), dpi=600, linewidth=1.0)

for i, parameter in enumerate(parameters):
    ax = plt.subplot(nrows, ncols, i+1)

    ax.grid(True)
    ax.tick_params(direction='in')

    # palette = ['inferno', 'cubehelix', 'Spectral', 'viridis', 'seismic', 'magma']

    sns.boxplot(data=initial_data,
                x='Тип образца',
                y=parameter,
                width=0.2,
                palette='magma',
                showfliers=False,
                ax=ax)

    sns.stripplot(data=initial_data,
                  x='Тип образца',
                  y=parameter,
                  color='yellow',
                  alpha=point_alpha,
                  s=point_size,
                  linewidth=0.5,
                  ax=ax)

    ax.set_ylabel(parameter,
                  fontsize=16,
                  rotation=90,
                  labelpad=5)
    ax.set_xlabel('Тип образца',
                  fontsize=14,
                  rotation=0,
                  labelpad=5)

plt.tight_layout()

plt.savefig(path_to_save + '/boxplot.png', dpi=600)
plt.show()

# %% [markdown]
# *Analysis of features median values for each principal type of GO*

# %%
tmp_df_for_analysis = initial_data[['$d_{ср}, нм$', '$ζ, мВ$', 'Тип образца']]

# %%
print(
    f"ζ, мВ",
    f"(*) ОГ: {round(tmp.loc[tmp['Тип образца'] == '$ОГ$']['$ζ, мВ$'].median(), 2)}",
    f"(*) ОГ после диализа: {round(tmp.loc[tmp['Тип образца'] == '$ОГ_{диализ}$']['$ζ, мВ$'].median(), 2)}",
    f"(*) вОГ: {round(tmp.loc[tmp['Тип образца'] == '$ОГ$']['$ζ, мВ$'].median(), 2)}",
    sep="\n"
)
# Out:
# ζ, мВ
# (*) ОГ: -33.35
# (*) ОГ после диализа: -28.2
# (*) вОГ: -33.35

# %% [markdown]
# ## Violinplot

# %%
sns.set_theme()
plt.style.use('seaborn-v0_8-darkgrid')

parameters = data_visualization.columns[:-1]

nrows = 1
ncols = 3


fig = plt.figure(figsize=(11.7, 5), dpi=600, linewidth=1.0)

for i, parameter in enumerate(parameters):
    ax = plt.subplot(nrows, ncols, i+1)

    ax.grid(True)
    ax.tick_params(direction='in')

    sns.violinplot(data=initial_data,
                   x='Тип образца',
                   y=parameter,
                   palette='magma',
                   ax=ax)

    ax.set_ylabel(parameter,
                  fontname='DejaVu Sans',
                  fontsize=16,
                  rotation=90,
                  labelpad=5)
    ax.set_xlabel('Тип образца',
                  fontname='DejaVu Sans',
                  fontsize=14,
                  rotation=0,
                  labelpad=5)

    plt.tight_layout()

plt.savefig(path_to_save + '/violinplot.png', dpi=600)
plt.show()
